# %%
import pandas as pd
df = pd.read_csv("train_users_2.csv")
df
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# ...            ...                  ...                     ...
# 213446  zxodksqpep           2014-06-30          20140630235636
# 213447  mhewnxesx9           2014-06-30          20140630235719
# 213448  6o3arsjbb4           2014-06-30          20140630235754
# 213449  jh95kwisub           2014-06-30          20140630235822
# 213450  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# ...

# %%
if '9uqfg8txu3' in  df['id'].values:
    print("yes")

# %%
df_sessions = pd.read_csv("Sessions.csv")
df_sessions
# Out:
#              user_id            action action_type  \
# 0         d1mm9tcy42            lookup         NaN
# 1         d1mm9tcy42    search_results       click
# 2         d1mm9tcy42            lookup         NaN
# 3         d1mm9tcy42    search_results       click
# 4         d1mm9tcy42            lookup         NaN
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 0                                 NaN  Windows Desktop         319.0
# 1                 view_search_results  Windows Desktop       67753.0
# 2                                 NaN  Windows Desktop         301.0
# 3                 view_search_results  Windows Desktop       22141.0
# ...

# %%
df_sessions['device_type'].unique()
# Out:
# array(['Windows Desktop', '-unknown-', 'Mac Desktop', 'Android Phone',
#        'iPhone', 'iPad Tablet', 'Android App Unknown Phone/Tablet',
#        'Linux Desktop', 'Tablet', 'Chromebook', 'Blackberry', 'iPodtouch',
#        'Windows Phone', 'Opera Phone'], dtype=object)

# %%
df_countries = pd.read_csv("countries.csv")
df_countries
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
# 5                  GB        54.633220        -3.432277    6883.6590
# 6                  IT        41.873990        12.564167    8636.6310
# 7                  NL        52.133057         5.295250    7524.3203
# 8                  PT        39.553444        -7.839319    7355.2534
# 9                  US        36.966427       -95.844030       0.0000
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# ...

# %%
df_age = pd.read_csv("age_gender_bkts.csv")
df_age
# Out:
#     age_bucket country_destination  gender  population_in_thousands    year
# 0         100+                  AU    male                      1.0  2015.0
# 1        95-99                  AU    male                      9.0  2015.0
# 2        90-94                  AU    male                     47.0  2015.0
# 3        85-89                  AU    male                    118.0  2015.0
# 4        80-84                  AU    male                    199.0  2015.0
# ..         ...                 ...     ...                      ...     ...
# 415      95-99                  US    male                    115.0  2015.0
# 416      90-94                  US    male                    541.0  2015.0
# 417      15-19                  US  female                  10570.0  2015.0
# 418      85-89                  US    male                   1441.0  2015.0
# 419      80-84                  US    male                   2442.0  2015.0
#
# [420 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# id                              0
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         124543
# gender                          0
# age                         87990
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6065
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination             0
# dtype: int64

# %% [markdown]
# df['date_account_created'] = df['date_account_created'].astype('datetime64')

# %%
df.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %%
df['date_first_booking'] = df['date_first_booking'].fillna('No Booking')

# %%
df['gender'].unique()
# Out:
# array(['-unknown-', 'MALE', 'FEMALE', 'OTHER'], dtype=object)

# %%
import numpy as np
df['gender'] = df['gender'].replace('-unknown-',np.nan)

# %%
df['gender'].unique()
# Out:
# array([nan, 'MALE', 'FEMALE', 'OTHER'], dtype=object)

# %%
df.dropna(axis='index',how='any',inplace=True)

# %%
df
# Out:
#                 id date_account_created  timestamp_first_active  \
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 6       lsw9q7uk0j           2010-01-02          20100102012558
# 7       0d01nltbrs           2010-01-03          20100103191905
# ...            ...                  ...                     ...
# 213440  04y8115avm           2014-06-30          20140630234933
# 213441  omlc9iku7t           2014-06-30          20140630235151
# 213443  0k26r3mir0           2014-06-30          20140630235340
# 213445  qbxza0xojf           2014-06-30          20140630235547
# 213446  zxodksqpep           2014-06-30          20140630235636
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 1              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# date_account_created       0
# timestamp_first_active     0
# date_first_booking         0
# gender                     0
# age                        0
# signup_method              0
# signup_flow                0
# language                   0
# affiliate_channel          0
# affiliate_provider         0
# first_affiliate_tracked    0
# signup_app                 0
# first_device_type          0
# first_browser              0
# country_destination        0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# FEMALE    56820
# MALE      49739
# OTHER       228
# Name: gender, dtype: int64

# %%
df.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %%
df['date_account_created'] = df['date_account_created'].astype('datetime64')

# %%
df.dtypes
# Out:
# id                                 object
# date_account_created       datetime64[ns]
# timestamp_first_active              int64
# date_first_booking                 object
# gender                             object
# age                               float64
# signup_method                      object
# signup_flow                         int64
# language                           object
# affiliate_channel                  object
# affiliate_provider                 object
# first_affiliate_tracked            object
# signup_app                         object
# first_device_type                  object
# first_browser                      object
# country_destination                object
# dtype: object

# %%
df.reset_index(inplace=True)
#df.drop(labels=('index'),inplace=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25          20090523174809
# 1       4ft3gnwmtx           2010-09-28          20090609231247
# 2       bjjt8pjhuk           2011-12-05          20091031060129
# 3       lsw9q7uk0j           2010-01-02          20100102012558
# 4       0d01nltbrs           2010-01-03          20100103191905
# ...            ...                  ...                     ...
# 106782  04y8115avm           2014-06-30          20140630234933
# 106783  omlc9iku7t           2014-06-30          20140630235151
# 106784  0k26r3mir0           2014-06-30          20140630235340
# 106785  qbxza0xojf           2014-06-30          20140630235547
# 106786  zxodksqpep           2014-06-30          20140630235636
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 0              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
df_sessions.isna().sum()
# Out:
# user_id            34496
# action             79626
# action_type      1126204
# action_detail    1126204
# device_type            0
# secs_elapsed      136031
# dtype: int64

# %%
df_sessions
# Out:
#              user_id            action action_type  \
# 0         d1mm9tcy42            lookup         NaN
# 1         d1mm9tcy42    search_results       click
# 2         d1mm9tcy42            lookup         NaN
# 3         d1mm9tcy42    search_results       click
# 4         d1mm9tcy42            lookup         NaN
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 0                                 NaN  Windows Desktop         319.0
# 1                 view_search_results  Windows Desktop       67753.0
# 2                                 NaN  Windows Desktop         301.0
# 3                 view_search_results  Windows Desktop       22141.0
# ...

# %%
df_sessions['device_type'].value_counts()
# Out:
# Mac Desktop                         3594286
# Windows Desktop                     2658539
# iPhone                              2105031
# Android Phone                        839637
# iPad Tablet                          683414
# Android App Unknown Phone/Tablet     273652
# -unknown-                            211279
# Tablet                               139886
# Linux Desktop                         28373
# Chromebook                            22348
# iPodtouch                              8198
# Windows Phone                          2047
# Blackberry                              979
# Opera Phone                              68
# Name: device_type, dtype: int64

# %%
df_sessions['device_type'].replace('-unknown-','Others',inplace=True)

# %%
df_sessions['device_type'].value_counts()
# Out:
# Mac Desktop                         3594286
# Windows Desktop                     2658539
# iPhone                              2105031
# Android Phone                        839637
# iPad Tablet                          683414
# Android App Unknown Phone/Tablet     273652
# Others                               211279
# Tablet                               139886
# Linux Desktop                         28373
# Chromebook                            22348
# iPodtouch                              8198
# Windows Phone                          2047
# Blackberry                              979
# Opera Phone                              68
# Name: device_type, dtype: int64

# %%
df_sessions['action'].value_counts()
# Out:
# show              2768278
# index              843699
# search_results     725226
# personalize        706824
# search             536057
#                    ...
# deauthorize             1
# events                  1
# reactivate              1
# desks                   1
# nyan                    1
# Name: action, Length: 359, dtype: int64

# %%
cleaned_sessions_df = df_sessions.dropna(axis='index',how='any')

# %%
cleaned_sessions_df.isna().sum()
# Out:
# user_id          0
# action           0
# action_type      0
# action_detail    0
# device_type      0
# secs_elapsed     0
# dtype: int64

# %%
cleaned_sessions_df
# Out:
#              user_id            action action_type  \
# 1         d1mm9tcy42    search_results       click
# 3         d1mm9tcy42    search_results       click
# 5         d1mm9tcy42    search_results       click
# 7         d1mm9tcy42       personalize        data
# 8         d1mm9tcy42             index        view
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 1                 view_search_results  Windows Desktop       67753.0
# 3                 view_search_results  Windows Desktop       22141.0
# 5                 view_search_results  Windows Desktop        7703.0
# 7             wishlist_content_update  Windows Desktop         831.0
# ...

# %%
df.isna().sum()
# Out:
# id                         0
# date_account_created       0
# timestamp_first_active     0
# date_first_booking         0
# gender                     0
# age                        0
# signup_method              0
# signup_flow                0
# language                   0
# affiliate_channel          0
# affiliate_provider         0
# first_affiliate_tracked    0
# signup_app                 0
# first_device_type          0
# first_browser              0
# country_destination        0
# dtype: int64

# %%
df_age.isna().sum()
# Out:
# age_bucket                 0
# country_destination        0
# gender                     0
# population_in_thousands    0
# year                       0
# dtype: int64

# %%
cleaned_sessions_df['user_id'].duplicated().sum()
# Out:
# 9080052

# %%
df
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25          20090523174809
# 1       4ft3gnwmtx           2010-09-28          20090609231247
# 2       bjjt8pjhuk           2011-12-05          20091031060129
# 3       lsw9q7uk0j           2010-01-02          20100102012558
# 4       0d01nltbrs           2010-01-03          20100103191905
# ...            ...                  ...                     ...
# 106782  04y8115avm           2014-06-30          20140630234933
# 106783  omlc9iku7t           2014-06-30          20140630235151
# 106784  0k26r3mir0           2014-06-30          20140630235340
# 106785  qbxza0xojf           2014-06-30          20140630235547
# 106786  zxodksqpep           2014-06-30          20140630235636
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 0              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
df.dtypes
# Out:
# id                                 object
# date_account_created       datetime64[ns]
# timestamp_first_active              int64
# date_first_booking                 object
# gender                             object
# age                               float64
# signup_method                      object
# signup_flow                         int64
# language                           object
# affiliate_channel                  object
# affiliate_provider                 object
# first_affiliate_tracked            object
# signup_app                         object
# first_device_type                  object
# first_browser                      object
# country_destination                object
# dtype: object

# %%
df['date_account_created'].unique()
# Out:
# array(['2011-05-25T00:00:00.000000000', '2010-09-28T00:00:00.000000000',
#        '2011-12-05T00:00:00.000000000', ...,
#        '2014-06-27T00:00:00.000000000', '2014-06-29T00:00:00.000000000',
#        '2014-06-30T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['language'].unique()
# Out:
# array(['en', 'de', 'fr', 'es', 'pt', 'ko', 'zh', 'it', 'ru', 'ja', 'nl',
#        'sv', 'pl', 'hu', 'da', 'id', 'fi', 'no', 'tr', 'el', 'th', 'cs',
#        'hr', 'ca', 'is'], dtype=object)

# %%
cleaned_sessions_df.dtypes
# Out:
# user_id           object
# action            object
# action_type       object
# action_detail     object
# device_type       object
# secs_elapsed     float64
# dtype: object

# %%
cleaned_sessions_df
# Out:
#              user_id            action action_type  \
# 1         d1mm9tcy42    search_results       click
# 3         d1mm9tcy42    search_results       click
# 5         d1mm9tcy42    search_results       click
# 7         d1mm9tcy42       personalize        data
# 8         d1mm9tcy42             index        view
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 1                 view_search_results  Windows Desktop       67753.0
# 3                 view_search_results  Windows Desktop       22141.0
# 5                 view_search_results  Windows Desktop        7703.0
# 7             wishlist_content_update  Windows Desktop         831.0
# ...

# %%
df_age.dtypes
# Out:
# age_bucket                  object
# country_destination         object
# gender                      object
# population_in_thousands    float64
# year                       float64
# dtype: object

# %%
df_countries.dtypes
# Out:
# country_destination               object
# lat_destination                  float64
# lng_destination                  float64
# distance_km                      float64
# destination_km2                  float64
# destination_language              object
# language_levenshtein_distance    float64
# dtype: object

# %%
df
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25          20090523174809
# 1       4ft3gnwmtx           2010-09-28          20090609231247
# 2       bjjt8pjhuk           2011-12-05          20091031060129
# 3       lsw9q7uk0j           2010-01-02          20100102012558
# 4       0d01nltbrs           2010-01-03          20100103191905
# ...            ...                  ...                     ...
# 106782  04y8115avm           2014-06-30          20140630234933
# 106783  omlc9iku7t           2014-06-30          20140630235151
# 106784  0k26r3mir0           2014-06-30          20140630235340
# 106785  qbxza0xojf           2014-06-30          20140630235547
# 106786  zxodksqpep           2014-06-30          20140630235636
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 0              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
df['timestamp_first_active'] = df['timestamp_first_active'].astype('str')

# %%
updated_list =[ ele[0:4]+'-'+ele[4:6]+'-'+ele[6:8]+' '+ele[8:10]+':'+ele[10:12]+':'+ele[12:] for ele in np.array(df['timestamp_first_active'])]

# %%
df['timestamp_first_active'] = updated_list

# %%
df
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 1       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 2       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 3       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 4       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# ...            ...                  ...                    ...
# 106782  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 106783  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 106784  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 106785  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 106786  zxodksqpep           2014-06-30    2014-06-30 23:56:36
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 0              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
df
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 1       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 2       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 3       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 4       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# ...            ...                  ...                    ...
# 106782  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 106783  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 106784  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 106785  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 106786  zxodksqpep           2014-06-30    2014-06-30 23:56:36
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 0              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
import mysql.connector
mysql_db=mysql.connector.connect(host="localhost",user="root",password="@whisper301",database="Airbnb_41")

# %%
mycursor=mysql_db.cursor()

# %% [markdown]
# pip install mysqlclient

# %% [markdown]
# #from sqlalchemy import create_engine
# engine = create_engine("mysql://root:@whisper301@localhost:3306/Airbnb")
# #df.to_sql(name="users", con=mysql_db,schema='Airbnb',if_exists="append")

# %%
data_age_bkts=list(df_age.itertuples(index=False, name=None))
sql_stmnt_age_bkts = "INSERT IGNORE INTO age_gender_bkts_41(age_bucket, country_destination, gender, population_in_thousands, year) values(%s,%s,%s,%s,%s)"
mycursor.executemany(sql_stmnt_age_bkts,data_age_bkts)
mysql_db.commit()

# %%
data_countries=list(df_countries.itertuples(index=False, name=None))
sql_stmnt_countries = "INSERT IGNORE INTO countries_41(country_destination, lat_destination, long_destination, distance_km, distance_km2, destination_language, language_levenshtein_distance) values(%s,%s,%s,%s,%s,%s,%s)"
mycursor.executemany(sql_stmnt_countries,data_countries)
mysql_db.commit()

# %%
users_data=list(df.itertuples(index=False, name=None))
sql_stmnt_users = "INSERT IGNORE INTO users_41(id, date_account_created, timestamp_first_active, date_first_booking, gender, age, signup_method, signup_flow, language, affiliate_channel, affiliate_provider, first_affiliate_tracked, signup_app, first_device_type, first_browser, country_destination) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

# %%
cleaned_sessions_df
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 1       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 2       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 3       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 4       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# ...            ...                  ...                    ...
# 106782  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 106783  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 106784  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 106785  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 106786  zxodksqpep           2014-06-30    2014-06-30 23:56:36
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 0              No Booking    MALE  38.0      facebook            0       en
# ...

# %%
data_session=list(cleaned_sessions_df.itertuples(index=False, name=None))
sql_stmnt_sessions = "INSERT IGNORE INTO sessions_41(user_id, action, action_type, action_detail, device_type, secs_elapsed) values(%s,%s,%s,%s,%s,%s)"
mycursor.executemany(sql_stmnt_sessions,data_session)
mysql_db.commit()

# %%
df.dtypes
# Out:
# id                         object
# date_account_created       object
# timestamp_first_active     object
# date_first_booking         object
# gender                     object
# age                         int64
# signup_method              object
# signup_flow                 int64
# language                   object
# affiliate_channel          object
# affiliate_provider         object
# first_affiliate_tracked    object
# signup_app                 object
# first_device_type          object
# first_browser              object
# country_destination        object
# dtype: object

# %%
df.to_excel('users_41.xlsx', index=False)

# %%
cleaned_sessions_df
# Out:
#              user_id            action action_type  \
# 1         d1mm9tcy42    search_results       click
# 3         d1mm9tcy42    search_results       click
# 5         d1mm9tcy42    search_results       click
# 7         d1mm9tcy42       personalize        data
# 8         d1mm9tcy42             index        view
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 1                 view_search_results  Windows Desktop       67753.0
# 3                 view_search_results  Windows Desktop       22141.0
# 5                 view_search_results  Windows Desktop        7703.0
# 7             wishlist_content_update  Windows Desktop         831.0
# ...

# %%
df
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 1       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 2       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 3       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 4       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# ...            ...                  ...                    ...
# 106782  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 106783  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 106784  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 106785  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 106786  zxodksqpep           2014-06-30    2014-06-30 23:56:36
#
#        date_first_booking  gender  age signup_method  signup_flow language  \
# 0              No Booking    MALE   38      facebook            0       en
# ...
